# %% [markdown]
# <a href="https://colab.research.google.com/github/haillluuuu/CPE201A_FP_CANOY/blob/main/Python_Fundamentals_Canoy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Identation

# %%
if 5 > 2:
  print("Five is Greater than Two!")
# Out:
# Five is Greater than Two!

# %% [markdown]
# Phyton Comments

# %%
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %% [markdown]
# Variable Naming Conventions

# %% [markdown]
# Python Variable

# %%
x = 1
a, b=0,-1
a, b, c=0,-1,2

#Others:
b = "Sally" #This is a type of string
